# %%
s = "jerry"

# %%
s1 = 'tom'

# %%
type(s)
# Out:
# str

# %%
type(s1)
# Out:
# str

# %%
l = [2,3,4,5,6,"sri" , 3+7j , True , 34.56]

# %%
type(l)
# Out:
# list

# %%
s
# Out:
# 'jerry'

# %%
s[0]
# Out:
# 'j'

# %%
s[2]
# Out:
# 'r'

# %%
l
# Out:
# [2, 3, 4, 5, 6, 'sri', (3+7j), True, 34.56]

# %%
l[8]
# Out:
# 34.56

# %%
l[-4]
# Out:
# 'sri'

# %%
l
# Out:
# [2, 3, 4, 5, 6, 'sri', (3+7j), True, 34.56]

# %%
l[1] = 300

# %%
l
# Out:
# [2, 300, 4, 5, 6, 'sri', (3+7j), True, 34.56]

# %%
l[4] = "pwskills"

# %%
l
# Out:
# [2, 300, 4, 5, 'pwskills', 'sri', (3+7j), True, 34.56]

# %%
s
# Out:
# 'jerry'

# %%
s[1] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 s[1] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'sadh'

# %%
s
# Out:
# 'sadh'
